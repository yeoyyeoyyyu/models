# %%
import tensorflow as tf
from keras import backend as K
from keras.models import Model
from keras.layers import Input, Conv2D, DepthwiseConv2D
from keras.layers import Dense, GlobalAveragePooling2D
from keras.layers import Activation, BatchNormalization
from keras.layers import Add, Multiply, Reshape
from keras.utils.vis_utils import plot_model

# %%
# activation function
def relu6(x):
    return K.relu(x, max_value=6.0)

def hard_swish(x):
    return x * K.relu(x + 3.0, max_value=6.0) / 6.0

# %%
def Act(x, nl):
    """
    choice activation function
    
    # params
    x: Tensor, input tensor of conv layer
    nl: String, nonlinear  activation function type
    """
    if nl == "HS":
        x = Activation(hard_swish)(x)
    if nl == "RE":
        x = Activation(relu6)(x)
    
    return x

# %%
def Conv(inputs, filters, kernel, strides, nl):
    """
    Convolution Block defines 2D convolution operation with BN and activation
    
    # params
    inputs: Tensor, input tensor of convolution layer
    filters: Integer, dimension of output space
    kernel: Integer or tuple/list of 2 integers
            specifying width and height of 2D convolution window
    strides: Integer or tuple/list of 2 integers
             specifying strides of convolution width and height
    nl: String, nonlinear activation function type
    
    # return
    output tensor
    """
    channel_axis = 1 if K.image_data_format() == "channels_first" else -1
    
    x = Conv2D(filters, kernel, padding="same", strides=strides, use_bias=False)(inputs)
    x = BatchNormalization(axis=channel_axis)(x)
    x = Act(x, nl)
        
    return x

# %%
def Squeeze(inputs):
    """
    Squeeze and Excitation define squeeze structure
    
    # params
    inputs: Tensor, input tensor of conv layer
    """
    channels = int(inputs.shape[-1])
    
    x = GlobalAveragePooling2D()(inputs)
    x = Dense(channels, activation="relu")(x)
    x = Dense(channels, activation="hard_sigmoid")(x)
    x = Reshape((1, 1, channels))(x)
    x = Multiply()([inputs, x])
    
    return x

# %%
def bottleneck(inputs, filters, kernel, e, s, squeeze, nl, alpha=1.0):
    """
    Bottleneck define basic bottleneck structure
    
    # params
    inputs: Tensor, input tensor of conv layer
    filters: Integer, dimension of output space
    kernel: Integer of tuple/list of 2 integers
            specifying width and height of 2D conv window
    e: Integer, expansion factor
       t is always applied to input size
    s: Integer of tuple/list of 2 integers
       specifying strides of conv width and height
    squeeze: Boolean, whether to use squeeze
    nl: String, nonlinear activation function type
    alpha: Integer, width multiplier
           If alpha < 1.0, proportionally decreases the number of filters in each layer.
           If alpha > 1.0, proportionally increases the number of filters in each layer.
           If alpha = 1.0, default number of filters from the paper are used at each layer.
    
    # return 
    output tensor
    """
    
    channel_axis = 1 if K.image_data_format() == "channels_first" else -1
    input_shape = tf.keras.backend.int_shape(inputs)
    
    tchannel = int(e)
    cchannel = int(alpha * filters)
    
    r = s == 1 and input_shape[3] == filters
    
    x = Conv(inputs, tchannel, (1, 1), (1, 1), nl)
    x = DepthwiseConv2D(kernel, strides=(s, s), depth_multiplier=1, padding="same")(x)
    x = BatchNormalization(axis=channel_axis)(x)
    x = Act(x, nl)
    
    if squeeze:
        x = Squeeze(x)
    
    x = Conv2D(cchannel, (1, 1), strides=(1, 1), padding="same", use_bias=False)(x)
    x = BatchNormalization(axis=channel_axis)(x)
    
    if r:
        x = Add()([x, inputs])
    
    return x

# %%
def build(shape=(224, 224, 3), n_class=1000, alpha=1.0, include_top=True, pooling=None, plot=False):
    """
    build MobilNetV3 Small
    
    # params
    shape
    """
    inputs = Input(shape=shape)
    
    x = Conv(inputs, 16, kernel=3, strides=2, nl="HS")
    
    x = bottleneck(x, 16, kernel=3, e=16, s=2, squeeze=True, nl="RE")
    x = bottleneck(x, 24, kernel=3, e=72, s=2, squeeze=False, nl="RE")
    x = bottleneck(x, 24, kernel=3, e=88, s=1, squeeze=False, nl="RE")
    x = bottleneck(x, 40, kernel=5, e=96, s=2, squeeze=True, nl="HS")
    x = bottleneck(x, 40, kernel=5, e=240, s=1, squeeze=True, nl="HS")
    x = bottleneck(x, 40, kernel=5, e=240, s=1, squeeze=True, nl="HS")
    x = bottleneck(x, 48, kernel=5, e=120, s=1, squeeze=True, nl="HS")
    x = bottleneck(x, 48, kernel=5, e=144, s=1, squeeze=True, nl="HS")
    x = bottleneck(x, 96, kernel=5, e=288, s=2, squeeze=True, nl="HS")
    x = bottleneck(x, 96, kernel=5, e=576, s=1, squeeze=True, nl="HS")
    x = bottleneck(x, 96, kernel=5, e=576, s=1, squeeze=True, nl="HS")
    
    x = Conv(x, 576, kernel=1, strides=1, nl="HS")
    # feature extraction
    #-------------------------------------------------------------------#
    # pooling - none(default), avg(global average pooling), max(global max pooling)
    if pooling == 'avg':
        x = GlobalAveragePooling2D()(x)
        x = Reshape((1, 1, 576))(x)

        x = Conv2D(1280, kernel_size=1, padding="same")(x)
        x = Act(x, "HS")
        
    if pooling == 'max':
        x = GlobalMaxPooling2D()(x)
        x = Reshape((1, 1, 576))(x)

        x = Conv2D(1280, kernel_size=1, padding="same")(x)
        x = Act(x, "HS")
        
    # if include_top is False, can construct custom layers
    if include_top:
        x = Conv2D(n_class, kernel_size=1, padding="same", activation="softmax")(x)
        x = Reshape((n_class,))(x)
        
    model = Model(inputs, x)
    
    if plot:
        plot_model(model, to_file="MobileNetV3_small.png", show_shapes=True)
    
    return model

# %%
def train():
    model = build(plot=True, include_top=False)

# %%
model = build(plot=True, include_top=False)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 112, 112, 16  448         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 112, 112, 16  64         ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 112, 112, 16  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 112, 112, 16  272         ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 112, 112, 16  64         ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 112, 112, 16  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  depthwise_conv2d (DepthwiseCon  (None, 56, 56, 16)  160         ['activation_1[0][0]']
#  v2D)
#
#  batch_normalization_2 (BatchNo  (None, 56, 56, 16)  64          ['depthwise_conv2d[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 56, 56, 16)   0           ['batch_normalization_2[0][0]']
#
#  global_average_pooling2d (Glob  (None, 16)          0           ['activation_2[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 16)           272         ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense_1 (Dense)                (None, 16)           272         ['dense[0][0]']
#
#  reshape (Reshape)              (None, 1, 1, 16)     0           ['dense_1[0][0]']
#
#  multiply (Multiply)            (None, 56, 56, 16)   0           ['activation_2[0][0]',
#                                                                   'reshape[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 56, 56, 16)   272         ['multiply[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 56, 56, 16)  64          ['conv2d_2[0][0]']
#  rmalization)
#
#  conv2d_3 (Conv2D)              (None, 56, 56, 72)   1224        ['batch_normalization_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 56, 56, 72)  288         ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 56, 56, 72)   0           ['batch_normalization_4[0][0]']
#
#  depthwise_conv2d_1 (DepthwiseC  (None, 28, 28, 72)  720         ['activation_3[0][0]']
#  onv2D)
#
#  batch_normalization_5 (BatchNo  (None, 28, 28, 72)  288         ['depthwise_conv2d_1[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 28, 28, 72)   0           ['batch_normalization_5[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 28, 28, 24)   1752        ['activation_4[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 28, 28, 24)  96          ['conv2d_4[0][0]']
#  rmalization)
#
#  conv2d_5 (Conv2D)              (None, 28, 28, 88)   2200        ['batch_normalization_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 28, 28, 88)  352         ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 28, 28, 88)   0           ['batch_normalization_7[0][0]']
#
#  depthwise_conv2d_2 (DepthwiseC  (None, 28, 28, 88)  880         ['activation_5[0][0]']
#  onv2D)
#
#  batch_normalization_8 (BatchNo  (None, 28, 28, 88)  352         ['depthwise_conv2d_2[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 28, 28, 88)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 28, 28, 24)   2136        ['activation_6[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 28, 28, 24)  96          ['conv2d_6[0][0]']
#  rmalization)
#
#  add (Add)                      (None, 28, 28, 24)   0           ['batch_normalization_9[0][0]',
#                                                                   'batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 28, 28, 96)   2400        ['add[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 28, 28, 96)  384         ['conv2d_7[0][0]']
#  ormalization)
#
#  activation_7 (Activation)      (None, 28, 28, 96)   0           ['batch_normalization_10[0][0]']
#
#  depthwise_conv2d_3 (DepthwiseC  (None, 14, 14, 96)  2496        ['activation_7[0][0]']
#  onv2D)
#
#  batch_normalization_11 (BatchN  (None, 14, 14, 96)  384         ['depthwise_conv2d_3[0][0]']
#  ormalization)
#
#  activation_8 (Activation)      (None, 14, 14, 96)   0           ['batch_normalization_11[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 96)          0           ['activation_8[0][0]']
#  obalAveragePooling2D)
#
#  dense_2 (Dense)                (None, 96)           9312        ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
#  dense_3 (Dense)                (None, 96)           9312        ['dense_2[0][0]']
#
#  reshape_1 (Reshape)            (None, 1, 1, 96)     0           ['dense_3[0][0]']
#
#  multiply_1 (Multiply)          (None, 14, 14, 96)   0           ['activation_8[0][0]',
#                                                                   'reshape_1[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 14, 14, 40)   3880        ['multiply_1[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 14, 14, 40)  160         ['conv2d_8[0][0]']
#  ormalization)
#
#  conv2d_9 (Conv2D)              (None, 14, 14, 240)  9840        ['batch_normalization_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 14, 14, 240)  960        ['conv2d_9[0][0]']
#  ormalization)
#
#  activation_9 (Activation)      (None, 14, 14, 240)  0           ['batch_normalization_13[0][0]']
#
#  depthwise_conv2d_4 (DepthwiseC  (None, 14, 14, 240)  6240       ['activation_9[0][0]']
#  onv2D)
#
#  batch_normalization_14 (BatchN  (None, 14, 14, 240)  960        ['depthwise_conv2d_4[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 14, 14, 240)  0           ['batch_normalization_14[0][0]']
#
#  global_average_pooling2d_2 (Gl  (None, 240)         0           ['activation_10[0][0]']
#  obalAveragePooling2D)
#
#  dense_4 (Dense)                (None, 240)          57840       ['global_average_pooling2d_2[0][0
#                                                                  ]']
#
#  dense_5 (Dense)                (None, 240)          57840       ['dense_4[0][0]']
#
#  reshape_2 (Reshape)            (None, 1, 1, 240)    0           ['dense_5[0][0]']
#
#  multiply_2 (Multiply)          (None, 14, 14, 240)  0           ['activation_10[0][0]',
#                                                                   'reshape_2[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 14, 14, 40)   9640        ['multiply_2[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 14, 14, 40)  160         ['conv2d_10[0][0]']
#  ormalization)
#
#  add_1 (Add)                    (None, 14, 14, 40)   0           ['batch_normalization_15[0][0]',
#                                                                   'batch_normalization_12[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 14, 14, 240)  9840        ['add_1[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 14, 14, 240)  960        ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 14, 14, 240)  0           ['batch_normalization_16[0][0]']
#
#  depthwise_conv2d_5 (DepthwiseC  (None, 14, 14, 240)  6240       ['activation_11[0][0]']
#  onv2D)
#
#  batch_normalization_17 (BatchN  (None, 14, 14, 240)  960        ['depthwise_conv2d_5[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 14, 14, 240)  0           ['batch_normalization_17[0][0]']
#
#  global_average_pooling2d_3 (Gl  (None, 240)         0           ['activation_12[0][0]']
#  obalAveragePooling2D)
#
#  dense_6 (Dense)                (None, 240)          57840       ['global_average_pooling2d_3[0][0
#                                                                  ]']
#
#  dense_7 (Dense)                (None, 240)          57840       ['dense_6[0][0]']
#
#  reshape_3 (Reshape)            (None, 1, 1, 240)    0           ['dense_7[0][0]']
#
#  multiply_3 (Multiply)          (None, 14, 14, 240)  0           ['activation_12[0][0]',
#                                                                   'reshape_3[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 14, 14, 40)   9640        ['multiply_3[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 14, 14, 40)  160         ['conv2d_12[0][0]']
#  ormalization)
#
#  add_2 (Add)                    (None, 14, 14, 40)   0           ['batch_normalization_18[0][0]',
#                                                                   'add_1[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 14, 14, 120)  4920        ['add_2[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 14, 14, 120)  480        ['conv2d_13[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 14, 14, 120)  0           ['batch_normalization_19[0][0]']
#
#  depthwise_conv2d_6 (DepthwiseC  (None, 14, 14, 120)  3120       ['activation_13[0][0]']
#  onv2D)
#
#  batch_normalization_20 (BatchN  (None, 14, 14, 120)  480        ['depthwise_conv2d_6[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 14, 14, 120)  0           ['batch_normalization_20[0][0]']
#
#  global_average_pooling2d_4 (Gl  (None, 120)         0           ['activation_14[0][0]']
#  obalAveragePooling2D)
#
#  dense_8 (Dense)                (None, 120)          14520       ['global_average_pooling2d_4[0][0
#                                                                  ]']
#
#  dense_9 (Dense)                (None, 120)          14520       ['dense_8[0][0]']
#
#  reshape_4 (Reshape)            (None, 1, 1, 120)    0           ['dense_9[0][0]']
#
#  multiply_4 (Multiply)          (None, 14, 14, 120)  0           ['activation_14[0][0]',
#                                                                   'reshape_4[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 14, 14, 48)   5808        ['multiply_4[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 14, 14, 48)  192         ['conv2d_14[0][0]']
#  ormalization)
#
#  conv2d_15 (Conv2D)             (None, 14, 14, 144)  7056        ['batch_normalization_21[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 14, 14, 144)  576        ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 14, 14, 144)  0           ['batch_normalization_22[0][0]']
#
#  depthwise_conv2d_7 (DepthwiseC  (None, 14, 14, 144)  3744       ['activation_15[0][0]']
#  onv2D)
#
#  batch_normalization_23 (BatchN  (None, 14, 14, 144)  576        ['depthwise_conv2d_7[0][0]']
#  ormalization)
#
#  activation_16 (Activation)     (None, 14, 14, 144)  0           ['batch_normalization_23[0][0]']
#
#  global_average_pooling2d_5 (Gl  (None, 144)         0           ['activation_16[0][0]']
#  obalAveragePooling2D)
#
#  dense_10 (Dense)               (None, 144)          20880       ['global_average_pooling2d_5[0][0
#                                                                  ]']
#
#  dense_11 (Dense)               (None, 144)          20880       ['dense_10[0][0]']
#
#  reshape_5 (Reshape)            (None, 1, 1, 144)    0           ['dense_11[0][0]']
#
#  multiply_5 (Multiply)          (None, 14, 14, 144)  0           ['activation_16[0][0]',
#                                                                   'reshape_5[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 14, 14, 48)   6960        ['multiply_5[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 14, 14, 48)  192         ['conv2d_16[0][0]']
#  ormalization)
#
#  add_3 (Add)                    (None, 14, 14, 48)   0           ['batch_normalization_24[0][0]',
#                                                                   'batch_normalization_21[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 14, 14, 288)  14112       ['add_3[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 14, 14, 288)  1152       ['conv2d_17[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 14, 14, 288)  0           ['batch_normalization_25[0][0]']
#
#  depthwise_conv2d_8 (DepthwiseC  (None, 7, 7, 288)   7488        ['activation_17[0][0]']
#  onv2D)
#
#  batch_normalization_26 (BatchN  (None, 7, 7, 288)   1152        ['depthwise_conv2d_8[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 7, 7, 288)    0           ['batch_normalization_26[0][0]']
#
#  global_average_pooling2d_6 (Gl  (None, 288)         0           ['activation_18[0][0]']
#  obalAveragePooling2D)
#
#  dense_12 (Dense)               (None, 288)          83232       ['global_average_pooling2d_6[0][0
#                                                                  ]']
#
#  dense_13 (Dense)               (None, 288)          83232       ['dense_12[0][0]']
#
#  reshape_6 (Reshape)            (None, 1, 1, 288)    0           ['dense_13[0][0]']
#
#  multiply_6 (Multiply)          (None, 7, 7, 288)    0           ['activation_18[0][0]',
#                                                                   'reshape_6[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 7, 7, 96)     27744       ['multiply_6[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 7, 7, 96)    384         ['conv2d_18[0][0]']
#  ormalization)
#
#  conv2d_19 (Conv2D)             (None, 7, 7, 576)    55872       ['batch_normalization_27[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 7, 7, 576)   2304        ['conv2d_19[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 7, 7, 576)    0           ['batch_normalization_28[0][0]']
#
#  depthwise_conv2d_9 (DepthwiseC  (None, 7, 7, 576)   14976       ['activation_19[0][0]']
#  onv2D)
#
#  batch_normalization_29 (BatchN  (None, 7, 7, 576)   2304        ['depthwise_conv2d_9[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 7, 7, 576)    0           ['batch_normalization_29[0][0]']
#
#  global_average_pooling2d_7 (Gl  (None, 576)         0           ['activation_20[0][0]']
#  obalAveragePooling2D)
#
#  dense_14 (Dense)               (None, 576)          332352      ['global_average_pooling2d_7[0][0
#                                                                  ]']
#
#  dense_15 (Dense)               (None, 576)          332352      ['dense_14[0][0]']
#
#  reshape_7 (Reshape)            (None, 1, 1, 576)    0           ['dense_15[0][0]']
#
#  multiply_7 (Multiply)          (None, 7, 7, 576)    0           ['activation_20[0][0]',
#                                                                   'reshape_7[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 7, 7, 96)     55392       ['multiply_7[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 7, 7, 96)    384         ['conv2d_20[0][0]']
#  ormalization)
#
#  add_4 (Add)                    (None, 7, 7, 96)     0           ['batch_normalization_30[0][0]',
#                                                                   'batch_normalization_27[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 7, 7, 576)    55872       ['add_4[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 7, 7, 576)   2304        ['conv2d_21[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 7, 7, 576)    0           ['batch_normalization_31[0][0]']
#
#  depthwise_conv2d_10 (Depthwise  (None, 7, 7, 576)   14976       ['activation_21[0][0]']
#  Conv2D)
#
#  batch_normalization_32 (BatchN  (None, 7, 7, 576)   2304        ['depthwise_conv2d_10[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 7, 7, 576)    0           ['batch_normalization_32[0][0]']
#
#  global_average_pooling2d_8 (Gl  (None, 576)         0           ['activation_22[0][0]']
#  obalAveragePooling2D)
#
#  dense_16 (Dense)               (None, 576)          332352      ['global_average_pooling2d_8[0][0
#                                                                  ]']
#
#  dense_17 (Dense)               (None, 576)          332352      ['dense_16[0][0]']
#
#  reshape_8 (Reshape)            (None, 1, 1, 576)    0           ['dense_17[0][0]']
#
#  multiply_8 (Multiply)          (None, 7, 7, 576)    0           ['activation_22[0][0]',
#                                                                   'reshape_8[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 7, 7, 96)     55392       ['multiply_8[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 7, 7, 96)    384         ['conv2d_22[0][0]']
#  ormalization)
#
#  add_5 (Add)                    (None, 7, 7, 96)     0           ['batch_normalization_33[0][0]',
#                                                                   'add_4[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 7, 7, 576)    55872       ['add_5[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 7, 7, 576)   2304        ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 7, 7, 576)    0           ['batch_normalization_34[0][0]']
#
# ==================================================================================================
# Total params: 2,301,072
# Trainable params: 2,288,928
# Non-trainable params: 12,144
# __________________________________________________________________________________________________
